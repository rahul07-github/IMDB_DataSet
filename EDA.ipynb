# %%
# imdb Movie dataset ----------------------
import pandas as pd
df=pd.read_csv('imdb_data.csv')
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
print(df.columns)
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
df.shape
# Out:
# (3000, 23)

# %%
df.iloc[3]
# Out:
# id                                                                       4
# belongs_to_collection                                                  NaN
# budget                                                             1200000
# genres                   [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# homepage                                        http://kahaanithefilm.com/
# imdb_id                                                          tt1821480
# original_language                                                       hi
# original_title                                                     Kahaani
# overview                 Vidya Bagchi (Vidya Balan) arrives in Kolkata ...
# popularity                                                        3.174936
# poster_path                               /aTXRaPrWSinhcmCrcfJK17urp3F.jpg
# production_companies                                                   NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %%
df['genres'] # column name and genres
# Out:
# 0                          [{'id': 35, 'name': 'Comedy'}]
# 1       [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                           [{'id': 18, 'name': 'Drama'}]
# 3       [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4       [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#                               ...
# 2995    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996    [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997    [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998    [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999    [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
# Name: genres, Length: 3000, dtype: object

# %%
df[df['original_title']=="Kahaani"]
# Out:
#    id belongs_to_collection   budget  \
# 3   4                   NaN  1200000
#
#                                               genres  \
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
#
#                      homepage    imdb_id original_language original_title  \
# 3  http://kahaanithefilm.com/  tt1821480                hi        Kahaani
#
#                                             overview  popularity  ...  \
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
#
#   release_date runtime                                   spoken_languages  \
# 3       3/9/12   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
#
#      status  tagline    title  \
# 3  Released      NaN  Kahaani
#
#                                             Keywords  \
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
#
#                                                 cast  \
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
#
# ...

# %%
df[df['original_title']=="Kahaani"][['budget','status']]
# Out:
#     budget    status
# 3  1200000  Released

# %% [markdown]
# 27/5/2025

# %%
import pandas as pd
df.sort_values(['budget'])
# Out:
#         id                              belongs_to_collection     budget  \
# 56      57                                                NaN          0
# 7        8                                                NaN          0
# 4        5                                                NaN          0
# 2112  2113                                                NaN          0
# 2600  2601                                                NaN          0
# ...    ...                                                ...        ...
# 1630  1631  [{'id': 8650, 'name': 'Transformers Collection...  260000000
# 1425  1426  [{'id': 8537, 'name': 'Superman Collection', '...  270000000
# 2770  2771  [{'id': 86311, 'name': 'The Avengers Collectio...  280000000
# 2209  2210  [{'id': 295, 'name': 'Pirates of the Caribbean...  300000000
# 2135  2136  [{'id': 295, 'name': 'Pirates of the Caribbean...  380000000
#
#                                                  genres  \
# ...

# %%
df.sort_values(['budget'],ascending=False) # find the sort of budget of movies
# Out:
#         id                              belongs_to_collection     budget  \
# 2135  2136  [{'id': 295, 'name': 'Pirates of the Caribbean...  380000000
# 2209  2210  [{'id': 295, 'name': 'Pirates of the Caribbean...  300000000
# 2770  2771  [{'id': 86311, 'name': 'The Avengers Collectio...  280000000
# 1425  1426  [{'id': 8537, 'name': 'Superman Collection', '...  270000000
# 1630  1631  [{'id': 8650, 'name': 'Transformers Collection...  260000000
# ...    ...                                                ...        ...
# 2996  2997                                                NaN          0
# 1993  1994                                                NaN          0
# 2000  2001                                                NaN          0
# 52      53                                                NaN          0
# 71      72                                                NaN          0
#
#                                                  genres  \
# ...

# %%
df.sort_values(['budget'],ascending=False)[["budget",'id']].head(1) # find the highest budget of movies
# Out:
#          budget    id
# 2135  380000000  2136

# %%
df.sort_values(['budget'],ascending=False)[['budget','id']].tail(1) # find the budget and id of the lowest budget of movie
# Out:
#     budget  id
# 71       0  72

# %%
# find the information of movie  with highest budget
df.sort_values(['budget'],ascending=False).head(1)
# Out:
#         id                              belongs_to_collection     budget  \
# 2135  2136  [{'id': 295, 'name': 'Pirates of the Caribbean...  380000000
#
#                                                  genres  \
# 2135  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
#
#                                                homepage    imdb_id  \
# 2135  http://disney.go.com/pirates/index-on-stranger...  tt1298650
#
#      original_language                               original_title  \
# 2135                en  Pirates of the Caribbean: On Stranger Tides
#
#                                                overview  popularity  ...  \
# 2135  Captain Jack Sparrow crosses paths with a woma...    27.88772  ...
#
#      release_date runtime                                   spoken_languages  \
# 2135      5/14/11   136.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
#
#         status                      tagline  \
# 2135  Released  Live Forever Or Die Trying.
#
# ...

# %%
df['budget'].mean() # avg of budget movies
# Out:
# np.float64(22531334.11)

# %%
df[['budget','original_title']].max() # find the name of highest budget and movie name also
# Out:
# budget            380000000
# original_title          회사원
# dtype: object

# %%
df['runtime'].max() # WAP to get the longest runtime
# Out:
# np.float64(338.0)

# %%
df['runtime'].min() # WAP to get the shortest runtime
# Out:
# np.float64(0.0)

# %%
#WAP to get those movie whose revenue more than 2 million and spent less than 1 million.
